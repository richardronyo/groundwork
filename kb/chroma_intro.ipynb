# %%
import chromadb

chroma_client = chromadb.Client()

# %%
collection = chroma_client.create_collection(name = "test_collection")

# %% [markdown]
# I can add to this collection with my own custom embeddings. How I will use Chroma is after getting dependecy relationships between the files, I will be getting an embedding relationship between the files and then adding them to Chroma
